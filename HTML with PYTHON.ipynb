# %%
import pandas as pd 
from pandas import read_html
from pandas import Series,DataFrame

# %%
url = 'https://en.wikipedia.org/wiki/List_of_banks_in_India'

# %%
df_llist = pd.io.html.read_html(url)
df_llist
# Out:
# [              Anchor Bank  Established          Headquarters  \
#  0          Bank of Baroda         1908     Vadodara, Gujarat
#  1           Bank of India         1906   Mumbai, Maharashtra
#  2     Bank of Maharashtra         1935     Pune, Maharashtra
#  3             Canara Bank         1906  Bengaluru, Karnataka
#  4   Central Bank of India         1911   Mumbai, Maharashtra
#  5             Indian Bank         1907   Chennai, Tamil Nadu
#  6    Indian Overseas Bank         1937   Chennai, Tamil Nadu
#  7    Punjab National Bank         1894             New Delhi
#  8    Punjab and Sind Bank         1908             New Delhi
#  9     Union Bank of India         1919   Mumbai, Maharashtra
#  10               UCO Bank         1943  Kolkata, West Bengal
#  11    State Bank of India         1955   Mumbai, Maharashtra
#
#     Government Shareholding  Branches                      Total Assets  \
#  0                   63.97%      8310  ₹12.03 trillion (US$150 billion)
# ...

# %%
dframe=df_llist[0]

# %%
dframe
# Out:
#               Anchor Bank  Established          Headquarters  \
# 0          Bank of Baroda         1908     Vadodara, Gujarat
# 1           Bank of India         1906   Mumbai, Maharashtra
# 2     Bank of Maharashtra         1935     Pune, Maharashtra
# 3             Canara Bank         1906  Bengaluru, Karnataka
# 4   Central Bank of India         1911   Mumbai, Maharashtra
# 5             Indian Bank         1907   Chennai, Tamil Nadu
# 6    Indian Overseas Bank         1937   Chennai, Tamil Nadu
# 7    Punjab National Bank         1894             New Delhi
# 8    Punjab and Sind Bank         1908             New Delhi
# 9     Union Bank of India         1919   Mumbai, Maharashtra
# 10               UCO Bank         1943  Kolkata, West Bengal
# 11    State Bank of India         1955   Mumbai, Maharashtra
#
#    Government Shareholding  Branches                      Total Assets  \
# 0                   63.97%      8310  ₹12.03 trillion (US$150 billion)
# ...

# %%
dframe.columns.values
# Out:
# array(['Anchor Bank', 'Established', 'Headquarters',
#        'Government Shareholding', 'Branches', 'Total Assets', 'Revenues',
#        'Refs'], dtype=object)
